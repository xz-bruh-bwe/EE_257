# %%
#Current File Path
# %pwd
# Out:
# 'C:\\Users\\Baron\\Desktop\\EE_257_Repo\\EE_257\\%ML_PATH_EE257%\\EE257_env\\Assignments\\Project'

# %%
#Import Necessary Liobraries
#This code block includes all libraries thus far...
import pandas as pd # Library associated with machine learning functions
import numpy as np # NumPy is the fundamental package for scientific computing in Python 

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

# Classification Models:

# Linear Models
import sklearn.linear_model as skl_lm # Linear Model
from sklearn.model_selection import train_test_split


#LDA and QDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

#Logistical Regression
from sklearn.linear_model import LogisticRegression

# Libraries for the Confusion Matrix, Classification report and the precision score
from sklearn.metrics import confusion_matrix, classification_report, precision_score



#Processing? Neighbors for KNN
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, precision_score, accuracy_score


# Stats models
import statsmodels.api as sm
import statsmodels.formula.api as smf

import random
import array

print('DONE INITIALIZATION')
# Out:
# DONE INITIALIZATION

# %%
# Import the Dataset
#This version has spaces in the labels:
dataset = pd.read_csv("data.csv", delimiter = ";")
#This version has no spaces in the labels:
dataset_ = pd.read_csv("data_no_spaces.csv", delimiter = ";")

# %%
#Retrieve general info about the data set
#dataset.info()
dataset_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Marital_status                                4424 non-null   int64
#  1   Application_mode                              4424 non-null   int64
#  2   Application_order                             4424 non-null   int64
#  3   Course                                        4424 non-null   int64
#  4   Daytime_evening_attendance                    4424 non-null   int64
#  5   Previous_qualification                        4424 non-null   int64
#  6   Previous_qualification_grade                  4424 non-null   float64
#  7   Nacionality                                   4424 non-null   int64
#  8   Mothers_qualification                         4424 non-null   int64
# ...

# %%
#Code that visualizes the dataset's input variables and possible features
dataset_.head()
# Out:
#    Marital_status  Application_mode  Application_order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime_evening_attendance  Previous_qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous_qualification_grade  Nacionality  Mothers_qualification  \
# 0                         122.0            1                     19
# 1                         160.0            1                      1
# ...

# %%
#Code to drop any null variables (Missing Variables in the dataset)

#dataset_clean = dataset.dropna()
#dataset_clean.info()

# %%
#Code to enumerize the dataset to be used when calling a specific coluimn for later use
#Numerize the dataset for visualization
    #for index, column_name in enumerate(dataset.columns):
    #    print(index, column_name)
    #for index, column_name in enumerate(dataset_.columns):
    #    print(index, column_name)

# %%
# Create a data frames for later use
df = pd.DataFrame(dataset)

#No space version
df_ = pd.DataFrame(dataset_)
#        
            
if (df_.equals(dataset_)):
    print('dataset equals df')
else:
    print('dataset does not equal df')
    
#If the output equals, then the dataset retrieved from the dataset and asserting it 
#was done correctly
# Out:
# dataset equals df

# %%
#Assign features according to the spec sheet.
#All Features
features = df[['Marital status', # Double brackets
            'Application mode',
            'Application order',
            'Course',
            'Daytime/evening attendance	',
            'Previous qualification',
            'Previous qualification (grade)',
            'Nacionality',
            "Mother's qualification",
            "Father's qualification",
            "Mother's occupation",
            "Father's occupation",
            'Admission grade',
            'Displaced',
            'Educational special needs',
            'Debtor',
            'Tuition fees up to date',
            'Gender',
            'Scholarship holder',
            'Age at enrollment',
            'International',
            'Curricular units 1st sem (credited)',
            'Curricular units 1st sem (enrolled)',
            'Curricular units 1st sem (evaluations)',
            'Curricular units 1st sem (approved)',
            'Curricular units 1st sem (grade)',
            'Curricular units 1st sem (without evaluations)',
            'Curricular units 2nd sem (credited)',
            'Curricular units 2nd sem (enrolled)',
            'Curricular units 2nd sem (evaluations)',
            'Curricular units 2nd sem (approved)',
            'Curricular units 2nd sem (grade)',
            'Curricular units 2nd sem (without evaluations)',
            'Unemployment rate',
            'Inflation rate',
            'GDP',
            ]]

#Assign the tartget
target = df_[['Target']]
#########################################################################
features_ = df_[['Marital_status', # Double brackets  
            'Application_mode',                                  
            'Application_order',                                 
            'Course',                                            
            'Daytime_evening_attendance',                        
            'Previous_qualification',                            
            'Previous_qualification_grade',                      
            'Nacionality',                                       
            'Mothers_qualification',                             
            'Fathers_qualification',                             
            'Mothers_occupation',                                
            'Fathers_occupation',                                
            'Admission_grade',                                   
            'Displaced',                                         
            'Educational_special_needs',                         
            'Debtor',                                            
            'Tuition_fees_up_to_date',                           
            'Gender',                                            
            'Scholarship_holder',                                
            'Age_at_enrollment',                                 
            'International',                                     
            'Curricular_units_1st_sem_credited',                 
            'Curricular_unit_1st_sem_enrolled',                  
            'Curricular_units_1st_sem_evaluations',              
            'Curricular_units_1st_sem_approved',                 
            'Curricular_units_1st_sem_grade',                    
            'Curricular_units_1st_sem_without_evaluations',      
            'Curricular_units_2nd_sem_credited',                 
            'Curricular_units_2nd_sem_enrolled',                 
            'Curricular_units_2nd_sem_evaluations',              
            'Curricular_units_2nd_sem_approved',                 
            'Curricular_units_2nd_sem_grade',                    
            'Curricular_units_2nd_sem_without_evaluations',      
            'Unemployment_rate',                                 
            'Inflation_rate',                                    
            'GDP'                                                                                         
            ]]

# %%
# Group by Features
    # groupby function obsolete?
#Demographic_data_grouped = df_.groupby(['Marital_status', # Double brackets                     
#                'Nacionality',                                                                       
#                'Displaced',                                                     
#                'Gender',                          
#                'Age_at_enrollment',                                 
#                'International'                                                                                                                          
#            ])
Demographic_data = df_[['Marital_status', # Double brackets                     
                'Nacionality',                                                                       
                'Displaced',                                                     
                'Gender',                          
                'Age_at_enrollment',                                 
                'International'                                                                                                                          
            ]]

Socioeconomic_data = df_[['Mothers_qualification',                             
                'Fathers_qualification',                             
                'Mothers_occupation',                                
                'Fathers_occupation',                       
                'Educational_special_needs',                         
                'Debtor',                                            
                'Tuition_fees_up_to_date',                                     
                'Scholarship_holder'                                                                                                                        
            ]]

Macroeconomic_data = df_[['Unemployment_rate',                                 
            'Inflation_rate',                                    
            'GDP'
             ]]
Academic_data_at_enrollment = df_[[ # Double brackets  
            'Application_mode',                                  
            'Application_order',                                 
            'Course',                                            
            'Daytime_evening_attendance',                        
            'Previous_qualification',                            
            'Previous_qualification_grade' #Missing in the spec sheet!                   
            ]] 
Academic_data_at_the_end_of_1st_sem = df_[[ 
            'Curricular_units_1st_sem_credited',                 
            'Curricular_unit_1st_sem_enrolled',                  
            'Curricular_units_1st_sem_evaluations',              
            'Curricular_units_1st_sem_approved',                 
            'Curricular_units_1st_sem_grade',                    
            'Curricular_units_1st_sem_without_evaluations'
]]# Double brackets  

Academic_data_at_the_end_of_2nd_sem = df_[[ 
            'Curricular_units_2nd_sem_credited',                 
            'Curricular_units_2nd_sem_enrolled',                 
            'Curricular_units_2nd_sem_evaluations',              
            'Curricular_units_2nd_sem_approved',                 
            'Curricular_units_2nd_sem_grade',                    
            'Curricular_units_2nd_sem_without_evaluations'
]]# Double brackets

# %%
#Simple x and y plot
# Specify type of plot and the axes
df_.plot(kind = "scatter", x= "Previous_qualification_grade", y = "Admission_grade", alpha=0.3)
# Out:
# <Axes: xlabel='Previous_qualification_grade', ylabel='Admission_grade'>

# %%
#Create histogram plots from the Specific Categories
Demographic_data.hist(bins = 20, figsize = (10,8))
plt.show()

Socioeconomic_data.hist(bins = 20, figsize = (10,8))
plt.show()
Macroeconomic_data.hist(bins = 20, figsize = (10,8))
plt.show()
Academic_data_at_enrollment.hist(bins = 20, figsize = (10,8))
plt.show()
Academic_data_at_the_end_of_1st_sem.hist(bins = 20, figsize = (10,8))
plt.show()
Academic_data_at_the_end_of_2nd_sem.hist(bins = 20, figsize = (10,8))
plt.show()

# %%
# Creating Box Plots:
# Then Repeat For others
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 5))

# Create boxplots for each column
for i, column in enumerate(Macroeconomic_data.columns):
    Macroeconomic_data.boxplot(column, ax=axes[i])

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
#Analyze the target pt 1
df_['Target'].describe()
# Out:
# count         4424
# unique           3
# top       Graduate
# freq          2209
# Name: Target, dtype: object

# %%
#Look at the target a histogram to understand the spread
df_['Target'].hist(bins = 3, figsize = (10,8))
plt.show()

# %%
#Code to enumerize the Target output
#yields: 
    #Dropout = 0
    #Graduate = 1
    #Enrolled = 2
#Change this to FACT!!
df_['Target2'] = df_['Target'].factorize()[0]
df_
# Out:
#       Marital_status  Application_mode  Application_order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime_evening_attendance  Previous_qualification  \
# 0                              1                       1
# ...

# %%
#Plotting the output classifications of the Target

#Create the grid
fig = plt.figure(figsize=(12,5))
gs = mpl.gridspec.GridSpec(1, 4)
ax1 = plt.subplot(gs[0,:-2])
ax2 = plt.subplot(gs[0,:-2])
ax3 = plt.subplot(gs[0,:-2])


#Enumerated Legend: 
    #Dropout = 0
    #Graduate = 1
    #Enrolled = 2

# Take a fraction of the samples where target value is '0'
df_dropout = df_[df_.Target2 == 0].sample(frac=0.15)

# Take all samples  where target value is '1'
df_graduate = df_[df_.Target2 == 1]

# Take all samples  where target value is '2'
df_enrolled = df_[df_.Target2 == 2]


#Concat function used instead of append
df_all = pd.concat([df_dropout, df_graduate, df_enrolled])

ax1.scatter(df_all[df_all.Target == 'Dropout'].Admission_grade, df_all[df_all.Target == 'Dropout'].Previous_qualification_grade, s=40, c='black', marker='+',
            linewidths=1)

ax1.scatter(df_all[df_all.Target == 'Enrolled'].Admission_grade, df_all[df_all.Target == 'Enrolled'].Previous_qualification_grade, s=40, c='orange', marker='o',
            linewidths=1)

ax1.scatter(df_all[df_all.Target == 'Graduate'].Admission_grade, df_all[df_all.Target == 'Graduate'].Previous_qualification_grade, s=40, c='green', marker='x',
            linewidths=1)

ax1.set_xlabel('Admission grade')
#ax1.set_xlim(xmin=-100)
ax1.set_ylabel('Previous qualification (grade)')


#c_palette = {'Dropout':'lightblue', 'Enrolled':'orange', 'Graduate':'green'} 
#sns.boxplot(x = 'Target', y = 'Admission_grade', data=df_,  orient='v', ax=ax2, palette=c_palette)
#sns.boxplot(x = 'Target', y = 'Previous_qualification_grade', data=df_, orient='v', ax=ax3, palette=c_palette)
#gs.tight_layout(plt.gcf())



#Enumerated Legend: 
    #Dropout  = 0
    #Graduate = 1
    #Enrolled = 2

#Include the box plots
# Out:
# Text(0, 0.5, 'Previous qualification (grade)')

# %%
#Box Plots from previous graph

#Enumerated Legend: 
    #Dropout  = 0
    #Graduate = 1
    #Enrolled = 2

c_palette = {'Dropout':'lightblue', 'Enrolled':'orange', 'Graduate':'green'}
sns.boxplot(x = 'Target', y = 'Admission_grade', data=df_,  orient='v', ax=ax2, palette=c_palette)
sns.boxplot(x = 'Target', y = 'Previous_qualification_grade', data=df_, orient='v', ax=ax3, palette=c_palette)
gs.tight_layout(plt.gcf())
# Out:
# C:\Users\Baron\AppData\Local\Temp\ipykernel_32236\1290395474.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Target', y = 'Admission_grade', data=df_,  orient='v', ax=ax2, palette=c_palette)
# C:\Users\Baron\AppData\Local\Temp\ipykernel_32236\1290395474.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'Target', y = 'Previous_qualification_grade', data=df_, orient='v', ax=ax3, palette=c_palette)

# %%
## Logistic Regression: Only used for binary classification

#Assert X
X_train = df_.Previous_qualification_grade.values.reshape(-1,1)

#Assert y
y = df_.Target2

clf = skl_lm.LogisticRegression(solver='newton-cg')

clf.fit(X_train,y)

print(clf)
print('classes: ',clf.classes_)
print('coefficients: ',clf.coef_)
print('intercept :', clf.intercept_)
# Out:
# LogisticRegression(solver='newton-cg')
# classes:  [0 1 2]
# coefficients:  [[-0.00595151]
#  [ 0.01129253]
#  [-0.00534102]]
# intercept : [ 0.83568665 -1.00920722  0.17352057]

# %%
#Multiple Logistic Regression via one vs rest method
# Assert X 
    #Add Constant adds column of ones for multiple logistic regression
X_train = sm.add_constant(df_[[ 'Marital_status', # Double brackets  
            'Application_mode',                                  
            'Application_order',                                 
            'Course',                                            
            'Daytime_evening_attendance',                        
            'Previous_qualification',                            
            'Previous_qualification_grade',                      
            'Nacionality',                                       
            'Mothers_qualification',                             
            'Fathers_qualification',                             
            'Mothers_occupation',                                
            'Fathers_occupation',                                
            'Admission_grade',                                   
            'Displaced',                                         
            'Educational_special_needs',                         
            'Debtor',                                            
            'Tuition_fees_up_to_date',                           
            'Gender',                                            
            'Scholarship_holder',                                
            'Age_at_enrollment',                                 
            'International',                                     
            'Curricular_units_1st_sem_credited',                 
            'Curricular_unit_1st_sem_enrolled',                  
            'Curricular_units_1st_sem_evaluations',              
            'Curricular_units_1st_sem_approved',                 
            'Curricular_units_1st_sem_grade',                    
            'Curricular_units_1st_sem_without_evaluations',      
            'Curricular_units_2nd_sem_credited',                 
            'Curricular_units_2nd_sem_enrolled',                 
            'Curricular_units_2nd_sem_evaluations',              
            'Curricular_units_2nd_sem_approved',                 
            'Curricular_units_2nd_sem_grade',                    
            'Curricular_units_2nd_sem_without_evaluations',      
            'Unemployment_rate',                                 
            'Inflation_rate',                                    
            'GDP'
            ]])
#Assert Y
y = df_.Target2

#Logisitic Regression Classifier for Mutliclass
clf = LogisticRegression(multi_class='auto', solver='liblinear')

clf.fit(X_train, y)

y_pred = clf.predict(X_train)

print(clf)
print('classes: ',clf.classes_)
print('coefficients: ',clf.coef_)
print('intercept :', clf.intercept_)

print("There are ... Coefficients",  len(clf.coef_))

accuracy = accuracy_score(y, y_pred)
print("Accuracy:", accuracy)
# Out:
# LogisticRegression(solver='liblinear')
# classes:  [0 1 2]
# coefficients:  [[-7.14327706e-02 -1.00561866e-01  4.76766709e-04  6.61055905e-02
#    6.67248826e-05  2.90580344e-02 -8.74913662e-03  3.14962441e-04
#    4.86975086e-03  9.42475808e-03 -3.66301795e-03 -1.26758147e-02
#    2.15787660e-03 -5.21257783e-03  2.57605420e-01  3.49639969e-02
#    6.72510647e-01 -1.88982594e+00  2.67270337e-01 -5.30476623e-01
#    4.58802305e-02 -1.68678306e-01  7.17475964e-02  2.95942869e-02
#   -1.12148605e-02 -2.88732610e-01  3.12082816e-02 -1.21545394e-01
#    2.17151151e-01  4.52830191e-01 -1.48009524e-02 -5.67647635e-01
#   -6.23986229e-02 -1.03670102e-01  6.94913392e-02  1.42988146e-02
#    1.51259479e-02]
#  [-9.69707120e-01  7.61129879e-02 -5.08734364e-03 -7.77655101e-03
#   -1.49757560e-04 -3.17544946e-02  1.33587040e-02  1.67766552e-04
#   -2.37093019e-02  3.46636966e-03  5.40975061e-03  6.14082357e-03
#   -5.82658857e-03  4.31397562e-03 -1.04149925e-01 -1.26973872e-01
# ...

# %%
#Create Confusion matrix for multiple linear regression
len(y)
len(y_pred)
confusion_matrix(y, y_pred)

df_.groupby([y_pred, 'Target']).size().unstack('Target')

#Legend
#Enumerated Legend: 
    #Dropout  = 0
    #Graduate = 1
    #Enrolled = 2
# Out:
# Target  Dropout  Enrolled  Graduate
# 0          1125       224        52
# 1           213       391      2109
# 2            83       179        48

# %%
#LDA Classifier

# Assert X
X = features_

#Assert y
y = df_.Target2

lda = LinearDiscriminantAnalysis(solver='svd')
y_pred = lda.fit(X, y).predict(X)

confusion_matrix(y, y_pred)

accuracy = accuracy_score(y, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7678571428571429
